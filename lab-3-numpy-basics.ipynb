# %% [markdown]
# # Numpy <hr style="border:2.5px solid rgba(190, 11, 200, 1) "></hr>

# %% [markdown]
# <b>REINALD DERIC E. AMAR</b>
# <br>COMPUTER ENGINEER

# %%
# imports and packages
import numpy as np

# %% [markdown]
# # 1D Array

# %%
my_array = np.array ([1,2,3])

# %%
type(my_array)
# Out:
# numpy.ndarray

# %%
np.shape(my_array)
# Out:
# (3,)

# %% [markdown]
# # 2D Array

# %%
my_array = np.array([
    [1,2,3],
    [4,5,6]
])
my_array
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])
